# %%
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(8,7)) # Creates a dataframe containing random numbers
df[df > 0.9] = np.nan # If a value in the table is greater than 0.9 - make it NaN 
df
# Out:
#           0         1         2         3         4         5         6
# 0 -0.958253       NaN  0.317612 -0.792592  0.856888 -0.477446 -0.072396
# 1  0.241015       NaN -1.103031  0.223124 -0.625883  0.439500 -2.574947
# 2       NaN -0.834878 -1.173812  0.879054 -0.498338       NaN       NaN
# 3       NaN -0.143416 -1.625237  0.446343 -0.738798       NaN  0.573147
# 4       NaN  0.347250 -0.144718 -0.953725 -1.726380 -2.492063 -0.672776
# 5 -0.252311 -0.536490  0.153002 -0.012974 -2.193638  0.326532       NaN
# 6 -0.345273  0.567436 -0.129502 -0.747451 -2.498044 -1.086833  0.195690
# 7       NaN -1.571705  0.895739 -1.912788       NaN -0.512129 -1.239151

# %%
print(df.isnull())
# Out:
#        0      1      2      3      4      5      6
# 0  False   True  False  False  False  False  False
# 1  False   True  False  False  False  False  False
# 2   True  False  False  False  False   True   True
# 3   True  False  False  False  False   True  False
# 4   True  False  False  False  False  False  False
# 5  False  False  False  False  False  False   True
# 6  False  False  False  False  False  False  False
# 7   True  False  False  False   True  False  False

# %%
print(df.isnull().sum())
# Out:
# 0    4
# 1    2
# 2    0
# 3    0
# 4    1
# 5    2
# 6    2
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 11

# %%
df.index = ['a','b','c','d','e','f','g','h'] 
df
# Out:
#           0         1         2         3         4         5         6
# a -0.958253       NaN  0.317612 -0.792592  0.856888 -0.477446 -0.072396
# b  0.241015       NaN -1.103031  0.223124 -0.625883  0.439500 -2.574947
# c       NaN -0.834878 -1.173812  0.879054 -0.498338       NaN       NaN
# d       NaN -0.143416 -1.625237  0.446343 -0.738798       NaN  0.573147
# e       NaN  0.347250 -0.144718 -0.953725 -1.726380 -2.492063 -0.672776
# f -0.252311 -0.536490  0.153002 -0.012974 -2.193638  0.326532       NaN
# g -0.345273  0.567436 -0.129502 -0.747451 -2.498044 -1.086833  0.195690
# h       NaN -1.571705  0.895739 -1.912788       NaN -0.512129 -1.239151

# %%
df.dropna()
# Out:
#           0         1         2         3         4         5        6
# g -0.345273  0.567436 -0.129502 -0.747451 -2.498044 -1.086833  0.19569

# %%
df.fillna(0, inplace=True) 
print(df)
# Out:
#           0         1         2         3         4         5         6
# a -0.958253  0.000000  0.317612 -0.792592  0.856888 -0.477446 -0.072396
# b  0.241015  0.000000 -1.103031  0.223124 -0.625883  0.439500 -2.574947
# c  0.000000 -0.834878 -1.173812  0.879054 -0.498338  0.000000  0.000000
# d  0.000000 -0.143416 -1.625237  0.446343 -0.738798  0.000000  0.573147
# e  0.000000  0.347250 -0.144718 -0.953725 -1.726380 -2.492063 -0.672776
# f -0.252311 -0.536490  0.153002 -0.012974 -2.193638  0.326532  0.000000
# g -0.345273  0.567436 -0.129502 -0.747451 -2.498044 -1.086833  0.195690
# h  0.000000 -1.571705  0.895739 -1.912788  0.000000 -0.512129 -1.239151

# %%
df = pd.DataFrame(np.random.randn(7,6)) 
df[df > 0.9] = np.nan
df
# Out:
#           0         1         2         3         4         5
# 0       NaN -0.891630  0.040163 -0.091607 -1.473017 -0.059836
# 1  0.572602  0.880046  0.857826 -0.021105  0.301064  0.516279
# 2       NaN       NaN       NaN  0.681373       NaN -0.055125
# 3 -0.782687       NaN       NaN  0.839387       NaN -0.745905
# 4 -0.387041  0.219831  0.108698 -0.466667  0.729512 -1.128855
# 5 -1.393341 -1.332449 -1.288161  0.356456       NaN -1.716667
# 6 -0.579745  0.512446 -0.056129 -1.137673  0.533330  0.261480

# %%
df[0].fillna(df[2].mean(), inplace = True) 
df
# Out:
#           0         1         2         3         4         5
# 0 -0.067521 -0.891630  0.040163 -0.091607 -1.473017 -0.059836
# 1  0.572602  0.880046  0.857826 -0.021105  0.301064  0.516279
# 2 -0.067521       NaN       NaN  0.681373       NaN -0.055125
# 3 -0.782687       NaN       NaN  0.839387       NaN -0.745905
# 4 -0.387041  0.219831  0.108698 -0.466667  0.729512 -1.128855
# 5 -1.393341 -1.332449 -1.288161  0.356456       NaN -1.716667
# 6 -0.579745  0.512446 -0.056129 -1.137673  0.533330  0.261480

# %%
for column_name in df: 
    df[column_name].fillna(df[column_name].mean(), inplace = True)
df
# Out:
#           0         1         2         3         4         5
# 0 -0.067521 -0.891630  0.040163 -0.091607 -1.473017 -0.059836
# 1  0.572602  0.880046  0.857826 -0.021105  0.301064  0.516279
# 2 -0.067521 -0.122351 -0.067521  0.681373  0.022722 -0.055125
# 3 -0.782687 -0.122351 -0.067521  0.839387  0.022722 -0.745905
# 4 -0.387041  0.219831  0.108698 -0.466667  0.729512 -1.128855
# 5 -1.393341 -1.332449 -1.288161  0.356456  0.022722 -1.716667
# 6 -0.579745  0.512446 -0.056129 -1.137673  0.533330  0.261480

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab 
import matplotlib 
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# read the data
df = pd.read_csv('Sberbank Housing Market.csv')

# %%
df.shape
# Out:
# (30471, 292)

# %%
df.dtypes
# Out:
# id                      int64
# timestamp              object
# full_sq                 int64
# life_sq               float64
# floor                 float64
#                        ...
# mosque_count_5000       int64
# leisure_count_5000      int64
# sport_count_5000        int64
# market_count_5000       int64
# price_doc               int64
# Length: 292, dtype: object

# %%
from pandas.plotting import scatter_matrix

# %%
## Step 1
df_fewer_columns = df.iloc[:, 15:20:1]

# %%
scatter_matrix(df_fewer_columns, figsize=(12, 12));

# %%
import missingno as msno

# %%
# Step 2
df_some_columns = df.iloc[:, 0:30:1]

# %%
msno.matrix(df_some_columns)
# Out:
# <AxesSubplot: >

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot: >

# %%
limitPer = len(df_some_columns) * .80 # 80% of the number of columns 
df_some_columns.dropna(axis='columns', thresh = limitPer, inplace = True)

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot: >

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot: >
